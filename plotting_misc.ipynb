# %%
import osmnx as ox
import networkx as nx
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon, LineString
from shapely.ops import polygonize
import numpy as np
from tqdm import tqdm
G = ox.graph_from_point((40.77892619481051, -73.9510420715686), 300, network_type="drive")

# %%
ox.plot_graph(G)

# %%
# plot from a point - Check the graph
import osmnx as ox
import matplotlib.pyplot as plt
import networkx as nx
import osmnx as ox
import numpy as np
G = ox.graph.graph_from_point((52.373097358907465, 4.893586296440393), 1000, dist_type='bbox', network_type='walk', simplify=True, retain_all=False, truncate_by_edge=False, custom_filter=None)

# Plot the road network
fig, ax = plt.subplots(figsize=(12, 12))
ax.set_facecolor('black')
ox.plot_graph(G, ax=ax, node_size=0, edge_color='gray', edge_linewidth=0.5, show=False)
plt.show()

# %%
# Polygon Analysis
import osmnx as ox
from shapely.geometry import Polygon
import matplotlib.pyplot as plt
import networkx as nx
import osmnx as ox
import numpy as np

# Define your polygon
Polygon = Polygon([
    (-6.2878217328002455, 53.34903696298475),
    (-6.28778003917356, 53.35060802322347),
    (-6.284465395839681, 53.350611134179985),
    (-6.284632170280776, 53.349083628959576),
    (-6.2878217328002455, 53.34903696298475),
])
# Get the street network within the polygon
GPL = ox.graph_from_polygon(Polygon, network_type='bike')


# Basic stats
Gs = ox.stats.basic_stats(GPL, area=None, clean_int_tol=None)
display(Gs)

# Get all edge lengths
edge_lengths = [d['length'] for u, v, k, d in GPL.edges(data=True, keys=True)]

# Calculate median
median_length = np.median(edge_lengths)
print(f"Median street length: {median_length:.2f} meters")

# Plot the road network
fig, ax = plt.subplots(figsize=(12, 12))
ax.set_facecolor('black')
ox.plot_graph(GPL, ax=ax, node_size=0, edge_color='gray', edge_linewidth=0.5, show=False)
plt.show()
# Out:
# {'n': 19,
#  'm': 38,
#  'k_avg': 4.0,
#  'edge_length_total': 1444.9532562596232,
#  'edge_length_avg': 38.02508569104272,
#  'streets_per_node_avg': 2.473684210526316,
#  'streets_per_node_counts': {0: 0, 1: 5, 2: 0, 3: 14},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.2631578947368421,
#   2: 0.0,
#   3: 0.7368421052631579},
#  'intersection_count': 14,
#  'street_length_total': 722.4766281298117,
#  'street_segment_count': 19,
#  'street_length_avg': 38.025085691042726,
#  'circuity_avg': 1.0511380571236908,
#  'self_loop_proportion': 0.0}
# Median street length: 33.97 meters
